# %%
for i in range(start=1000000,step=1000001,stop=100000000)
    x = [range(0,i)]
    println(x)
end
# Out:
# UnitRange{Int64}[0:1000000]
# UnitRange{Int64}[0:2000001]
# UnitRange{Int64}[0:3000002]
# UnitRange{Int64}[0:4000003]
# UnitRange{Int64}[0:5000004]
# UnitRange{Int64}[0:6000005]
# UnitRange{Int64}[0:7000006]
# UnitRange{Int64}[0:8000007]
# UnitRange{Int64}[0:9000008]
# UnitRange{Int64}[0:10000009]
# UnitRange{Int64}[0:11000010]
# UnitRange{Int64}[0:12000011]
# UnitRange{Int64}[0:13000012]
# UnitRange{Int64}[0:14000013]
# UnitRange{Int64}[0:15000014]
# UnitRange{Int64}[0:16000015]
# UnitRange{Int64}[0:17000016]
# UnitRange{Int64}[0:18000017]
# UnitRange{Int64}[0:19000018]
# UnitRange{Int64}[0:20000019]
# UnitRange{Int64}[0:21000020]
# UnitRange{Int64}[0:22000021]
# UnitRange{Int64}[0:23000022]
# UnitRange{Int64}[0:24000023]
# UnitRange{Int64}[0:25000024]
# UnitRange{Int64}[0:26000025]
# UnitRange{Int64}[0:27000026]
# UnitRange{Int64}[0:28000027]
# UnitRange{Int64}[0:29000028]
# UnitRange{Int64}[0:30000029]
# UnitRange{Int64}[0:31000030]
# UnitRange{Int64}[0:32000031]
# ...
