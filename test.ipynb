# %%
for i in range(start=1000000,step=1000000,stop=100000001)
    x=[range(0,i)]
    println(x)
end
# Out:
# UnitRange{Int64}[0:1000000]
# UnitRange{Int64}[0:2000000]
# UnitRange{Int64}[0:3000000]
# UnitRange{Int64}[0:4000000]
# UnitRange{Int64}[0:5000000]
# UnitRange{Int64}[0:6000000]
# UnitRange{Int64}[0:7000000]
# UnitRange{Int64}[0:8000000]
# UnitRange{Int64}[0:9000000]
# UnitRange{Int64}[0:10000000]
# UnitRange{Int64}[0:11000000]
# UnitRange{Int64}[0:12000000]
# UnitRange{Int64}[0:13000000]
# UnitRange{Int64}[0:14000000]
# UnitRange{Int64}[0:15000000]
# UnitRange{Int64}[0:16000000]
# UnitRange{Int64}[0:17000000]
# UnitRange{Int64}[0:18000000]
# UnitRange{Int64}[0:19000000]
# UnitRange{Int64}[0:20000000]
# UnitRange{Int64}[0:21000000]
# UnitRange{Int64}[0:22000000]
# UnitRange{Int64}[0:23000000]
# UnitRange{Int64}[0:24000000]
# UnitRange{Int64}[0:25000000]
# UnitRange{Int64}[0:26000000]
# UnitRange{Int64}[0:27000000]
# UnitRange{Int64}[0:28000000]
# UnitRange{Int64}[0:29000000]
# UnitRange{Int64}[0:30000000]
# UnitRange{Int64}[0:31000000]
# UnitRange{Int64}[0:32000000]
# ...
